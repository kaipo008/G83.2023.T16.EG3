# %% [markdown]
# <a href="https://colab.research.google.com/github/kaipo008/G83.2023.T16.EG3/blob/main/P1_G84_100472080_100472152.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Portada***
#
#
# ---
#
#
# ***Práctica 1: PREDICCIÓN DE LA PRODUCCIÓN DE ENERGÍA EÓLICA CON SCIKIT-LEARN***
#
# ---
#
# *Aprendizaje Automático*
#
# *Equipo 12*
#
# *Grupo 84*
#
# *Curso 2023-2024*
#
# ---
#
# 100472080@alumnos.uc3m.es - 100472080 - KAIXUAN ZHANG CHEN
#
# 100472152@alumnos.uc3m.es - 100472152 - ALVARO CABRERA NIETO
#
# ---
#
# Enlace a repositorio de GitHub: https://github.com/100472152/P1-G84-100472080-100472152
#
# ---

# %% [markdown]
# # ***Introducción***
#
# ---
#
# TODO: explicar los datos iniciales, comentarios e introducción a la práctica
#
#
#
#
#
#
#
#
# ---

# %%
# Importar la librería 'pandas' como 'pd'
import pandas as pd

# %%
# ************** IMPORTANTE **************
# Los archivos 'wind_ava.csv.gz' y ' wind_comp.csv.gz' deben estar subidos al
# entorno de ejecución antes de ejecutar la siguiente línea.

# Leer el archivo .csv comprimido en .gz
df = pd.read_csv("wind_ava.csv.gz",
                 compression="gzip"
                #  , usecols=["energy", "datetime", "p54.162.13"]
                 )


# Visualizar la información del archivo
df
# Out:
#                  datetime   energy     p54.162.1     p54.162.2     p54.162.3  \
# 0     2005-01-02 18:00:00   402.71  2.534970e+06  2.526864e+06  2.518754e+06
# 1     2005-01-03 00:00:00   696.80  2.537369e+06  2.529277e+06  2.521184e+06
# 2     2005-01-03 06:00:00  1591.15  2.533727e+06  2.525703e+06  2.517678e+06
# 3     2005-01-03 12:00:00  1338.62  2.534491e+06  2.526548e+06  2.518609e+06
# 4     2005-01-03 18:00:00   562.50  2.529543e+06  2.521623e+06  2.513702e+06
# ...                   ...      ...           ...           ...           ...
# 4743  2009-12-30 06:00:00  1280.13  2.407224e+06  2.400131e+06  2.393033e+06
# 4744  2009-12-30 12:00:00   855.00  2.407234e+06  2.400117e+06  2.393001e+06
# 4745  2009-12-30 18:00:00   117.06  2.401034e+06  2.393683e+06  2.386332e+06
# 4746  2009-12-31 12:00:00   516.96  2.393873e+06  2.386499e+06  2.379125e+06
# 4747  2009-12-31 18:00:00   867.07  2.392305e+06  2.384669e+06  2.377033e+06
#
# ...

# %% [markdown]
# # ***EDA simplificado***
#
# ---
#
# En este apartado comenzamos el Análisis Exploratorio de Datos o EDA (Exploratory Data Analysis) simplificado. Hemos empleado, entre otras fuentes, el material disponible en Aula Global y el sitio web Kaggle, en concreto: https://www.kaggle.com/code/rajmehra03/housing-prices-eda-regression-analysis
#
# TODO: utilizar solo la columna de energía y las que terminen en .13. Si hay datos constantes se pueden eliminar
#
#
#
#
#
#
#
#
# ---

# %% [markdown]
# # ***Evaluaciones 'outer' e 'inner'***
#
# ---
#
#
#
#
#
#
#
#
#
#
# ---
